# %% [markdown]
# # Set environment

# %%
import numpy as np
import pandas as pd
import os
from sklearn.model_selection import train_test_split, KFold
from sklearn.cross_validation import StratifiedShuffleSplit
from collections import Counter

FP_DAT = "/home/clint/GitRepo/Duke_BIOS824_Proj1/data/"
FP_LGG = "/data/Duke_BIOS824/LGG-segmentation/"
FP_OUT = "/data/Duke_BIOS824/res_proj01/"
# Out:
# /opt/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# # Import data

# %%
os.listdir(FP_LGG)
# Out:
# ['data.csv',
#  'README.md',
#  'TCGA_CS_4941_19960909',
#  'TCGA_CS_4942_19970222',
#  'TCGA_CS_4943_20000902',
#  'TCGA_CS_4944_20010208',
#  'TCGA_CS_5393_19990606',
#  'TCGA_CS_5395_19981004',
#  'TCGA_CS_5396_20010302',
#  'TCGA_CS_5397_20010315',
#  'TCGA_CS_6186_20000601',
#  'TCGA_CS_6188_20010812',
#  'TCGA_CS_6290_20000917',
#  'TCGA_CS_6665_20010817',
#  'TCGA_CS_6666_20011109',
#  'TCGA_CS_6668_20011025',
#  'TCGA_CS_6669_20020102',
#  'TCGA_DU_5849_19950405',
#  'TCGA_DU_5851_19950428',
#  'TCGA_DU_5852_19950709',
#  'TCGA_DU_5853_19950823',
#  'TCGA_DU_5854_19951104',
#  'TCGA_DU_5855_19951217',
#  'TCGA_DU_5871_19941206',
#  'TCGA_DU_5872_19950223',
#  'TCGA_DU_5874_19950510',
#  'TCGA_DU_6399_19830416',
#  'TCGA_DU_6400_19830518',
#  'TCGA_DU_6401_19831001',
#  'TCGA_DU_6404_19850629',
#  'TCGA_DU_6407_19860514',
#  'TCGA_DU_6408_19860521',
#  'TCGA_DU_7008_19830723',
#  'TCGA_DU_7010_19860307',
#  'TCGA_DU_7013_19860523',
#  'TCGA_DU_7014_19860618',
#  'TCGA_DU_7018_19911220',
#  'TCGA_DU_7019_19940908',
#  'TCGA_DU_7294_19890104',
#  'TCGA_DU_7298_19910324',
#  'TCGA_DU_7299_19910417',
#  'TCGA_DU_7300_19910814',
#  'TCGA_DU_7301_19911112',
#  'TCGA_DU_7302_19911203',
#  'TCGA_DU_7304_19930325',
#  'TCGA_DU_7309_19960831',
#  'TCGA_DU_8162_19961029',
#  'TCGA_DU_8163_19961119',
#  'TCGA_DU_8164_19970111',
#  'TCGA_DU_8165_19970205',
#  'TCGA_DU_8166_19970322',
#  'TCGA_DU_8167_19970402',
#  'TCGA_DU_8168_19970503',
#  'TCGA_DU_A5TP_19970614',
#  'TCGA_DU_A5TR_19970726',
#  'TCGA_DU_A5TS_19970726',
#  'TCGA_DU_A5TT_19980318',
#  'TCGA_DU_A5TU_19980312',
#  'TCGA_DU_A5TW_19980228',
#  'TCGA_DU_A5TY_19970709',
#  'TCGA_CS_6667_20011105',
#  'TCGA_DU_6405_19851005',
#  'TCGA_DU_7306_19930512',
#  'TCGA_EZ_7264_20010816',
#  'TCGA_HT_7475_19970918',
#  'TCGA_HT_7877_19980917',
#  'TCGA_FG_5962_20000626',
#  'TCGA_FG_5964_20010511',
#  'TCGA_FG_6688_20020215',
#  'TCGA_FG_6689_20020326',
#  'TCGA_FG_6690_20020226',
#  'TCGA_FG_6691_20020405',
#  'TCGA_FG_6692_20020606',
#  'TCGA_FG_7634_20000128',
#  'TCGA_FG_7637_20000922',
#  'TCGA_FG_7643_20021104',
#  'TCGA_FG_8189_20030516',
#  'TCGA_FG_A4MT_20020212',
#  'TCGA_FG_A4MU_20030903',
#  'TCGA_FG_A60K_20040224',
#  'TCGA_HT_7473_19970826',
#  'TCGA_HT_7602_19951103',
#  'TCGA_HT_7605_19950916',
#  'TCGA_HT_7608_19940304',
#  'TCGA_HT_7616_19940813',
#  'TCGA_HT_7680_19970202',
#  'TCGA_HT_7684_19950816',
#  'TCGA_HT_7686_19950629',
#  'TCGA_HT_7690_19960312',
#  'TCGA_HT_7692_19960724',
#  'TCGA_HT_7693_19950520',
#  'TCGA_HT_7694_19950404',
#  'TCGA_HT_7855_19951020',
#  'TCGA_HT_7856_19950831',
#  'TCGA_HT_7860_19960513',
#  'TCGA_HT_7874_19950902',
#  'TCGA_HT_7879_19981009',
#  'TCGA_HT_7881_19981015',
#  'TCGA_HT_7882_19970125',
#  'TCGA_HT_7884_19980913',
#  'TCGA_HT_8018_19970411',
#  'TCGA_HT_8105_19980826',
#  'TCGA_HT_8106_19970727',
#  'TCGA_HT_8107_19980708',
#  'TCGA_HT_8111_19980330',
#  'TCGA_HT_8113_19930809',
#  'TCGA_HT_8114_19981030',
#  'TCGA_HT_8563_19981209',
#  'TCGA_HT_A5RC_19990831',
#  'TCGA_HT_A616_19991226',
#  'TCGA_HT_A61A_20000127',
#  'TCGA_HT_A61B_19991127']

# %%
labels = pd.read_csv(os.path.join(FP_LGG, "data.csv"))
labels.shape
# Out:
# (110, 18)

# %%
labels.head()
# Out:
#         Patient  RNASeqCluster  MethylationCluster  miRNACluster  CNCluster  \
# 0  TCGA_CS_4941            2.0                 4.0             2        2.0
# 1  TCGA_CS_4942            1.0                 5.0             2        1.0
# 2  TCGA_CS_4943            1.0                 5.0             2        1.0
# 3  TCGA_CS_4944            NaN                 5.0             2        1.0
# 4  TCGA_CS_5393            4.0                 5.0             2        1.0
#
#    RPPACluster  OncosignCluster  COCCluster  histological_type  \
# 0          NaN              3.0           2                1.0
# 1          1.0              2.0           1                1.0
# 2          2.0              2.0           1                1.0
# 3          2.0              1.0           1                1.0
# 4          2.0              3.0           1                1.0
#
#    neoplasm_histologic_grade  tumor_tissue_site  laterality  tumor_location  \
# 0                        2.0                1.0         3.0             2.0
# 1                        2.0                1.0         3.0             2.0
# 2                        2.0                1.0         1.0             2.0
# 3                        1.0                1.0         3.0             6.0
# 4                        2.0                1.0         1.0             6.0
#
#    gender  age_at_initial_pathologic  race  ethnicity  death01
# 0     2.0                       67.0   3.0        2.0      1.0
# 1     1.0                       44.0   2.0        NaN      1.0
# 2     2.0                       37.0   3.0        NaN      0.0
# 3     2.0                       50.0   3.0        NaN      0.0
# 4     2.0                       39.0   3.0        NaN      0.0

# %% [markdown]
# # Train-test split

# %% [markdown]
# get the target columns

# %%
label_selected = labels.loc[:, ["Patient", "COCCluster", "neoplasm_histologic_grade"]]
label_selected.head(2)
# Out:
#         Patient  COCCluster  neoplasm_histologic_grade
# 0  TCGA_CS_4941           2                        2.0
# 1  TCGA_CS_4942           1                        2.0

# %% [markdown]
# train-test split

# %%
y_raw = label_selected.dropna().copy()
y_na  = label_selected.iloc[-1:, :]

y = y_raw.loc[:,["COCCluster", "neoplasm_histologic_grade"]].values
y_train, y_test = train_test_split(y_raw, test_size=9, random_state=123, stratify=y)

print(Counter(y_train['COCCluster']))
print(Counter(y_test['COCCluster']))
print("===========")
print(Counter(y_train['neoplasm_histologic_grade']))
print(Counter(y_test['neoplasm_histologic_grade']))
# Out:
# Counter({1: 50, 3: 28, 2: 22})
# Counter({1: 5, 2: 2, 3: 2})
# ===========
# Counter({2.0: 53, 1.0: 47})
# Counter({2.0: 5, 1.0: 4})

# %% [markdown]
# train-test-val split

# %%
### set and prepare split
kf = KFold(n_splits=10, shuffle = False, random_state = 123)
y_train2 = y_train.loc[:, ["Patient"]]
y_test2  = y_test.loc[ :, ["Patient"]]
y_na2    = y_na.loc[   :, ["Patient"]]

### init
y_new = label_selected.copy()
y_new = y_new.set_index("Patient")
idx = 0

### construct columns
for train_index, val_index in kf.split(y_train2):
    ### init loop
    idx += 1
    y1 = y_train2.iloc[train_index,:].copy()
    y2 = y_train2.iloc[  val_index,:].copy()
    y3 = y_test2.copy()
    y4 = y_na2.copy()
    
    ### construct column for cross-validation
    y1.loc[:, "cv" + str(idx).zfill(2)] = "train"
    y2.loc[:, "cv" + str(idx).zfill(2)] = "val"
    y3.loc[:, "cv" + str(idx).zfill(2)] = "test"
    y4.loc[:, "cv" + str(idx).zfill(2)] = "remove"
    
    ### join the columns together
    y_tmp = pd.concat([y1, y2, y3, y4]).set_index("Patient")
    y_new = y_new.join(y_tmp) 

### arrange results
label_new = y_new.sort_index().reset_index()

# %%
label_new
# Out:
#           Patient  COCCluster  neoplasm_histologic_grade    cv01    cv02  \
# 0    TCGA_CS_4941           2                        2.0   train   train
# 1    TCGA_CS_4942           1                        2.0   train   train
# 2    TCGA_CS_4943           1                        2.0   train   train
# 3    TCGA_CS_4944           1                        1.0   train     val
# 4    TCGA_CS_5393           1                        2.0   train   train
# 5    TCGA_CS_5395           2                        1.0   train   train
# 6    TCGA_CS_5396           3                        2.0   train   train
# 7    TCGA_CS_5397           2                        2.0   train   train
# 8    TCGA_CS_6186           2                        2.0     val   train
# 9    TCGA_CS_6188           2                        2.0   train   train
# 10   TCGA_CS_6290           1                        2.0   train   train
# 11   TCGA_CS_6665           1                        2.0   train   train
# 12   TCGA_CS_6666           1                        2.0   train   train
# 13   TCGA_CS_6667           1                        1.0   train     val
# 14   TCGA_CS_6668           3                        1.0   train   train
# 15   TCGA_CS_6669           1                        1.0    test    test
# 16   TCGA_DU_5849           3                        1.0   train   train
# 17   TCGA_DU_5851           1                        2.0   train   train
# 18   TCGA_DU_5852           2                        2.0   train   train
# 19   TCGA_DU_5853           1                        1.0   train   train
# 20   TCGA_DU_5854           2                        2.0   train   train
# 21   TCGA_DU_5855           1                        2.0   train   train
# 22   TCGA_DU_5871           1                        1.0   train     val
# 23   TCGA_DU_5872           1                        1.0   train   train
# 24   TCGA_DU_5874           3                        1.0   train     val
# 25   TCGA_DU_6399           1                        1.0   train     val
# 26   TCGA_DU_6400           3                        1.0     val   train
# 27   TCGA_DU_6401           1                        1.0   train   train
# 28   TCGA_DU_6404           2                        2.0    test    test
# 29   TCGA_DU_6405           2                        2.0   train   train
# ..            ...         ...                        ...     ...     ...
# 80   TCGA_HT_7608           3                        1.0   train   train
# 81   TCGA_HT_7616           3                        2.0   train   train
# 82   TCGA_HT_7680           1                        1.0   train   train
# 83   TCGA_HT_7684           3                        2.0   train   train
# 84   TCGA_HT_7686           2                        2.0   train   train
# 85   TCGA_HT_7690           1                        2.0   train   train
# 86   TCGA_HT_7692           3                        1.0   train   train
# 87   TCGA_HT_7693           3                        1.0   train     val
# 88   TCGA_HT_7694           3                        2.0   train   train
# 89   TCGA_HT_7855           1                        2.0   train   train
# 90   TCGA_HT_7856           3                        2.0   train   train
# 91   TCGA_HT_7860           2                        2.0   train   train
# 92   TCGA_HT_7874           3                        2.0   train   train
# 93   TCGA_HT_7877           3                        1.0     val   train
# 94   TCGA_HT_7879           1                        2.0     val   train
# 95   TCGA_HT_7881           3                        1.0    test    test
# 96   TCGA_HT_7882           2                        2.0   train   train
# 97   TCGA_HT_7884           1                        1.0   train     val
# 98   TCGA_HT_8018           1                        1.0   train   train
# 99   TCGA_HT_8105           3                        2.0   train   train
# 100  TCGA_HT_8106           2                        2.0     val   train
# 101  TCGA_HT_8107           1                        1.0   train   train
# 102  TCGA_HT_8111           1                        2.0   train   train
# 103  TCGA_HT_8113           1                        1.0   train   train
# 104  TCGA_HT_8114           1                        2.0   train   train
# 105  TCGA_HT_8563           2                        2.0    test    test
# 106  TCGA_HT_A5RC           2                        2.0   train   train
# 107  TCGA_HT_A616           1                        1.0   train   train
